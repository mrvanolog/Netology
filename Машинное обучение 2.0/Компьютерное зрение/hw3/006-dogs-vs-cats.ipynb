# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16

print(tf.__version__)
print(tf.executing_eagerly())
# Out:
# 2.2.0
# True

# %% [markdown]
# ## Функции загрузки данных

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

train_files = glob('data/train_sample/*.jpg')
test_files = glob('data/test_sample/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-5].output
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='dogs_vs_cats')

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 100353
# =================================================================
# Total params: 7,735,617
# Trainable params: 100,353
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
val_samples = 5  # число изображений в валидационной выборке

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором

# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=100,  # число эпох обучения
          validation_data=validation_data)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 49s 5s/step - loss: 369.9771 - accuracy: 0.6094 - val_loss: 500.9515 - val_accuracy: 0.4000
# Epoch 2/100
# 10/10 [==============================] - 48s 5s/step - loss: 135.2155 - accuracy: 0.7656 - val_loss: 450.5560 - val_accuracy: 0.4000
# Epoch 3/100
# 10/10 [==============================] - 48s 5s/step - loss: 65.5081 - accuracy: 0.8625 - val_loss: 48.1300 - val_accuracy: 0.6000
# Epoch 4/100
# 10/10 [==============================] - 49s 5s/step - loss: 54.1316 - accuracy: 0.8781 - val_loss: 16.6259 - val_accuracy: 0.8000
# Epoch 5/100
# 10/10 [==============================] - 53s 5s/step - loss: 47.1630 - accuracy: 0.9000 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 56s 6s/step - loss: 53.9170 - accuracy: 0.9125 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 7/100
# 10/10 [==============================] - 52s 5s/step - loss: 48.5065 - accuracy: 0.9062 - val_loss: 176.3055 - val_accuracy: 0.8000
# Epoch 8/100
# 10/10 [==============================] - 50s 5s/step - loss: 86.7185 - accuracy: 0.8562 - val_loss: 55.4507 - val_accuracy: 0.8000
# Epoch 9/100
# 10/10 [==============================] - 50s 5s/step - loss: 47.0572 - accuracy: 0.9062 - val_loss: 0.0593 - val_accuracy: 1.0000
# Epoch 10/100
# 10/10 [==============================] - 53s 5s/step - loss: 38.9254 - accuracy: 0.9062 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 11/100
# 10/10 [==============================] - 54s 5s/step - loss: 69.4755 - accuracy: 0.8781 - val_loss: 0.0626 - val_accuracy: 1.0000
# Epoch 12/100
# 10/10 [==============================] - 51s 5s/step - loss: 49.5870 - accuracy: 0.8813 - val_loss: 39.1161 - val_accuracy: 0.8000
# Epoch 13/100
# 10/10 [==============================] - 50s 5s/step - loss: 38.8330 - accuracy: 0.9031 - val_loss: 68.4664 - val_accuracy: 0.8000
# Epoch 14/100
# 10/10 [==============================] - 54s 5s/step - loss: 31.9384 - accuracy: 0.9219 - val_loss: 0.0681 - val_accuracy: 1.0000
# Epoch 15/100
# 10/10 [==============================] - 53s 5s/step - loss: 48.6695 - accuracy: 0.9062 - val_loss: 0.0697 - val_accuracy: 1.0000
# Epoch 16/100
# 10/10 [==============================] - 51s 5s/step - loss: 39.8395 - accuracy: 0.9062 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 17/100
# 10/10 [==============================] - 51s 5s/step - loss: 53.1382 - accuracy: 0.9031 - val_loss: 97.5439 - val_accuracy: 0.4000
# Epoch 18/100
# 10/10 [==============================] - 51s 5s/step - loss: 55.1762 - accuracy: 0.8844 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 19/100
# 10/10 [==============================] - 51s 5s/step - loss: 52.2992 - accuracy: 0.8969 - val_loss: 18.4963 - val_accuracy: 0.8000
# Epoch 20/100
# 10/10 [==============================] - 51s 5s/step - loss: 82.7465 - accuracy: 0.8687 - val_loss: 0.0783 - val_accuracy: 1.0000
# Epoch 21/100
# 10/10 [==============================] - 52s 5s/step - loss: 29.7196 - accuracy: 0.9406 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 22/100
# 10/10 [==============================] - 54s 5s/step - loss: 43.0909 - accuracy: 0.9125 - val_loss: 0.0815 - val_accuracy: 1.0000
# Epoch 23/100
# 10/10 [==============================] - 53s 5s/step - loss: 133.6067 - accuracy: 0.8594 - val_loss: 0.0833 - val_accuracy: 1.0000
# Epoch 24/100
# 10/10 [==============================] - 52s 5s/step - loss: 132.1370 - accuracy: 0.8469 - val_loss: 55.3097 - val_accuracy: 0.8000
# Epoch 25/100
# 10/10 [==============================] - 51s 5s/step - loss: 113.7134 - accuracy: 0.8719 - val_loss: 400.3417 - val_accuracy: 0.6000
# Epoch 26/100
# 10/10 [==============================] - 51s 5s/step - loss: 50.8956 - accuracy: 0.9281 - val_loss: 252.2830 - val_accuracy: 0.8000
# Epoch 27/100
# 10/10 [==============================] - 52s 5s/step - loss: 62.1915 - accuracy: 0.9187 - val_loss: 98.7413 - val_accuracy: 0.8000
# Epoch 28/100
# 10/10 [==============================] - 52s 5s/step - loss: 76.1542 - accuracy: 0.9344 - val_loss: 309.3325 - val_accuracy: 0.8000
# Epoch 29/100
# 10/10 [==============================] - 53s 5s/step - loss: 51.8582 - accuracy: 0.9375 - val_loss: 217.0805 - val_accuracy: 0.8000
# Epoch 30/100
# 10/10 [==============================] - 53s 5s/step - loss: 54.0770 - accuracy: 0.9375 - val_loss: 247.1212 - val_accuracy: 0.8000
# Epoch 31/100
# 10/10 [==============================] - 53s 5s/step - loss: 41.8914 - accuracy: 0.9250 - val_loss: 100.7511 - val_accuracy: 0.8000
# Epoch 32/100
# 10/10 [==============================] - 54s 5s/step - loss: 63.5712 - accuracy: 0.9219 - val_loss: 60.5530 - val_accuracy: 0.8000
# Epoch 33/100
# 10/10 [==============================] - 52s 5s/step - loss: 58.4327 - accuracy: 0.9094 - val_loss: 0.0977 - val_accuracy: 1.0000
# Epoch 34/100
# 10/10 [==============================] - 52s 5s/step - loss: 78.5233 - accuracy: 0.9281 - val_loss: 151.7784 - val_accuracy: 0.8000
# Epoch 35/100
# 10/10 [==============================] - 51s 5s/step - loss: 85.0395 - accuracy: 0.9125 - val_loss: 197.6183 - val_accuracy: 0.8000
# Epoch 36/100
# 10/10 [==============================] - 51s 5s/step - loss: 44.9772 - accuracy: 0.9375 - val_loss: 1.6230 - val_accuracy: 0.8000
# Epoch 37/100
# 10/10 [==============================] - 52s 5s/step - loss: 33.8156 - accuracy: 0.9469 - val_loss: 12.2618 - val_accuracy: 0.8000
# Epoch 38/100
# 10/10 [==============================] - 53s 5s/step - loss: 45.4746 - accuracy: 0.9281 - val_loss: 149.0050 - val_accuracy: 0.8000
# Epoch 39/100
# 10/10 [==============================] - 54s 5s/step - loss: 45.3812 - accuracy: 0.9344 - val_loss: 0.1046 - val_accuracy: 1.0000
# Epoch 40/100
# 10/10 [==============================] - 53s 5s/step - loss: 51.9212 - accuracy: 0.9125 - val_loss: 0.1058 - val_accuracy: 1.0000
# Epoch 41/100
# 10/10 [==============================] - 52s 5s/step - loss: 87.8302 - accuracy: 0.9187 - val_loss: 222.6253 - val_accuracy: 0.8000
# Epoch 42/100
# 10/10 [==============================] - 53s 5s/step - loss: 82.2334 - accuracy: 0.9250 - val_loss: 33.1586 - val_accuracy: 0.8000
# Epoch 43/100
# 10/10 [==============================] - 52s 5s/step - loss: 59.5827 - accuracy: 0.9250 - val_loss: 133.5405 - val_accuracy: 0.8000
# Epoch 44/100
# 10/10 [==============================] - 55s 6s/step - loss: 81.5226 - accuracy: 0.9156 - val_loss: 16.4020 - val_accuracy: 0.8000
# Epoch 45/100
# 10/10 [==============================] - 55s 5s/step - loss: 46.1551 - accuracy: 0.9250 - val_loss: 317.7946 - val_accuracy: 0.8000
# Epoch 46/100
# 10/10 [==============================] - 52s 5s/step - loss: 76.0196 - accuracy: 0.9312 - val_loss: 142.8449 - val_accuracy: 0.8000
# Epoch 47/100
# 10/10 [==============================] - 50s 5s/step - loss: 87.8030 - accuracy: 0.9281 - val_loss: 3.3127 - val_accuracy: 0.8000
# Epoch 48/100
# 10/10 [==============================] - 53s 5s/step - loss: 70.4055 - accuracy: 0.9219 - val_loss: 190.1072 - val_accuracy: 0.8000
# Epoch 49/100
# 10/10 [==============================] - 54s 5s/step - loss: 55.4987 - accuracy: 0.9531 - val_loss: 256.9608 - val_accuracy: 0.8000
# Epoch 50/100
# 10/10 [==============================] - 54s 5s/step - loss: 74.0735 - accuracy: 0.9438 - val_loss: 0.1169 - val_accuracy: 1.0000
# Epoch 51/100
# 10/10 [==============================] - 53s 5s/step - loss: 71.0777 - accuracy: 0.9438 - val_loss: 103.9204 - val_accuracy: 0.8000
# Epoch 52/100
# 10/10 [==============================] - 50s 5s/step - loss: 65.7905 - accuracy: 0.9469 - val_loss: 81.3887 - val_accuracy: 0.8000
# Epoch 53/100
# 10/10 [==============================] - 54s 5s/step - loss: 66.0648 - accuracy: 0.9281 - val_loss: 0.1195 - val_accuracy: 1.0000
# Epoch 54/100
# 10/10 [==============================] - 56s 6s/step - loss: 129.9236 - accuracy: 0.8938 - val_loss: 0.1207 - val_accuracy: 1.0000
# Epoch 55/100
# 10/10 [==============================] - 52s 5s/step - loss: 65.4982 - accuracy: 0.9219 - val_loss: 51.0769 - val_accuracy: 0.8000
# Epoch 56/100
# 10/10 [==============================] - 50s 5s/step - loss: 105.1564 - accuracy: 0.9156 - val_loss: 0.1235 - val_accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - 53s 5s/step - loss: 65.9859 - accuracy: 0.9156 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 58/100
# 10/10 [==============================] - 57s 6s/step - loss: 101.7490 - accuracy: 0.9250 - val_loss: 182.1674 - val_accuracy: 0.8000
# Epoch 59/100
# 10/10 [==============================] - 52s 5s/step - loss: 66.7270 - accuracy: 0.9219 - val_loss: 0.1269 - val_accuracy: 1.0000
# Epoch 60/100
# 10/10 [==============================] - 51s 5s/step - loss: 51.4459 - accuracy: 0.9469 - val_loss: 0.1279 - val_accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - 53s 5s/step - loss: 53.7374 - accuracy: 0.9563 - val_loss: 0.1288 - val_accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - 54s 5s/step - loss: 90.9627 - accuracy: 0.9219 - val_loss: 0.1295 - val_accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - 52s 5s/step - loss: 83.6624 - accuracy: 0.9312 - val_loss: 13.7583 - val_accuracy: 0.8000
# Epoch 64/100
# 10/10 [==============================] - 52s 5s/step - loss: 41.4070 - accuracy: 0.9375 - val_loss: 0.1312 - val_accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - 54s 5s/step - loss: 73.2203 - accuracy: 0.9094 - val_loss: 0.1320 - val_accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - 54s 5s/step - loss: 72.5608 - accuracy: 0.9281 - val_loss: 0.1329 - val_accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 54s 5s/step - loss: 86.5042 - accuracy: 0.9187 - val_loss: 0.1339 - val_accuracy: 1.0000
# Epoch 68/100
# 10/10 [==============================] - 53s 5s/step - loss: 36.7623 - accuracy: 0.9469 - val_loss: 17.7970 - val_accuracy: 0.8000
# Epoch 69/100
# 10/10 [==============================] - 53s 5s/step - loss: 35.1705 - accuracy: 0.9438 - val_loss: 0.1360 - val_accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - 52s 5s/step - loss: 26.2286 - accuracy: 0.9563 - val_loss: 0.1366 - val_accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 53s 5s/step - loss: 70.2646 - accuracy: 0.9375 - val_loss: 0.1372 - val_accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 53s 5s/step - loss: 76.1429 - accuracy: 0.9281 - val_loss: 0.1379 - val_accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 53s 5s/step - loss: 38.7497 - accuracy: 0.9500 - val_loss: 0.1388 - val_accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 52s 5s/step - loss: 49.0998 - accuracy: 0.9344 - val_loss: 0.1397 - val_accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 52s 5s/step - loss: 76.3393 - accuracy: 0.9281 - val_loss: 0.1407 - val_accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - 52s 5s/step - loss: 59.9907 - accuracy: 0.9438 - val_loss: 0.1417 - val_accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 54s 5s/step - loss: 99.0391 - accuracy: 0.9187 - val_loss: 59.7966 - val_accuracy: 0.8000
# Epoch 78/100
# 10/10 [==============================] - 54s 5s/step - loss: 59.7039 - accuracy: 0.9438 - val_loss: 281.6355 - val_accuracy: 0.8000
# Epoch 79/100
# 10/10 [==============================] - 53s 5s/step - loss: 28.4430 - accuracy: 0.9750 - val_loss: 0.1446 - val_accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 52s 5s/step - loss: 44.9840 - accuracy: 0.9594 - val_loss: 0.1454 - val_accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 54s 5s/step - loss: 17.2918 - accuracy: 0.9656 - val_loss: 0.1460 - val_accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 53s 5s/step - loss: 28.2026 - accuracy: 0.9625 - val_loss: 0.1466 - val_accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 55s 6s/step - loss: 15.1666 - accuracy: 0.9844 - val_loss: 0.1470 - val_accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - 52s 5s/step - loss: 29.8390 - accuracy: 0.9719 - val_loss: 0.1473 - val_accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - 55s 5s/step - loss: 25.8857 - accuracy: 0.9688 - val_loss: 0.1477 - val_accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 54s 5s/step - loss: 32.4989 - accuracy: 0.9719 - val_loss: 0.1482 - val_accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 54s 5s/step - loss: 73.4092 - accuracy: 0.9469 - val_loss: 0.1487 - val_accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 54s 5s/step - loss: 9.2577 - accuracy: 0.9656 - val_loss: 0.1494 - val_accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 52s 5s/step - loss: 30.5556 - accuracy: 0.9750 - val_loss: 0.1499 - val_accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 52s 5s/step - loss: 19.3815 - accuracy: 0.9750 - val_loss: 0.1503 - val_accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 56s 6s/step - loss: 17.5824 - accuracy: 0.9750 - val_loss: 0.1507 - val_accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 52s 5s/step - loss: 12.6483 - accuracy: 0.9781 - val_loss: 2.7801 - val_accuracy: 0.8000
# Epoch 93/100
# 10/10 [==============================] - 51s 5s/step - loss: 33.5763 - accuracy: 0.9719 - val_loss: 0.1517 - val_accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 51s 5s/step - loss: 19.6474 - accuracy: 0.9531 - val_loss: 0.1523 - val_accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 53s 5s/step - loss: 20.8073 - accuracy: 0.9812 - val_loss: 0.1528 - val_accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 53s 5s/step - loss: 46.4274 - accuracy: 0.9656 - val_loss: 2.3899 - val_accuracy: 0.8000
# Epoch 97/100
# 10/10 [==============================] - 55s 5s/step - loss: 19.2934 - accuracy: 0.9781 - val_loss: 0.1538 - val_accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 51s 5s/step - loss: 20.5207 - accuracy: 0.9719 - val_loss: 0.1543 - val_accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 52s 5s/step - loss: 29.8253 - accuracy: 0.9688 - val_loss: 53.8596 - val_accuracy: 0.8000
# Epoch 100/100
# 10/10 [==============================] - 54s 5s/step - loss: 30.8955 - accuracy: 0.9656 - val_loss: 0.1553 - val_accuracy: 1.0000

# %%
model.save('cats-dogs-vgg16.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files))

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %% [markdown]
# ## Готовим данные для отправки

# %%
import re

with open('submit.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))

# %%
# LogLoss = 1.84

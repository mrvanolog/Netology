# %% [markdown]
# **Задание 1**

# %%
import pandas as pd

# %%
rating = pd.read_csv('ratings.csv')
movie = pd.read_csv('movies.csv')
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
five_star = rating.query('rating == 5.0')
top_rating = five_star.movieId.value_counts(ascending=False).head(1)

top_movie = movie.query(f'movieId == {top_rating.index[0]}')

top_movie
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# **Задание 2**

# %%
data = pd.read_csv('power.csv')

data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
baltic = data[ (data['country'] == 'Lithuania') 
                | (data['country'] == 'Latvia') 
                | (data['country'] == 'Estonia') ]

year = baltic[ (baltic['year'] >= 2005) & (baltic['year'] <= 2010) ]
              
category = year[ (year['category'] == 4) 
                  | (year['category'] == 12)
                  | (year['category'] == 21)]

#category.head(100)

new_data = category[ category['quantity'] >= 0 ]

quantity_sum = new_data.sum(axis = 0, skipna = True)[2]

print("Суммарное потребление стран Прибалтики:", quantity_sum)
# Out:
# Суммарное потребление стран Прибалтики: 240580.0

# %% [markdown]
# **Задание 3**

# %%
# все таблицы
pd.read_html('https://fortrader.org/quotes')
# Out:
# [                               Type    Last   Chg.  Chg.%  Time
#  0  Нефть (BRENT) Курс нефти сегодня  59.590 -0.030 -0.050   NaN
#  1   Нефть (WTI) Цены на нефть (WTI)  55.580 -0.050 -0.090   NaN
#  2          Сахар котировки на сахар  12.630  0.000  0.000   NaN
#  3                   Газ Цена на газ   2.217  0.028  1.279   NaN,
#                                      Type          Last      Chg.     Chg.%  \
#  0                      ВТБ Акции ОАО ВТБ       0.03814  -0.00015  -0.39175
#  1                 Газпром Акции газпрома     226.92000     +2.05   0.91000
#  2                    Лукоил Акции Лукойл    5171.50000    +109.5   2.20000
#  3                Роснефть Акции Роснефти     404.10000     -0.70  -0.17000
#  4               Сбербанк Акции Сбербанка     217.20000     -0.02  -0.01000
#  5   Сургутнефтегаз Акции Сургутнефтегаза      25.91000    +0.130   0.50400
#  6              Норникель Акции Норникель   15408.00000       -18  -0.00000
#  7               Аэрофлот Акции Аерофлота     109.00000    +12.19  12.59000
#  8            Северсталь Акции Северсталь     951.20000      +3.4   0.40000
#  9            Транснефть Акции транснефти  150050.00000   -16 250 -10.00000
#  10     Ростелеком Курс акций ростелекома      80.80000     +7.97  10.94000
#  11                     RUSAL акции RUSAL       3.08000     +0.01   0.33000
#
#      Time
#  0    NaN
#  1    NaN
#  2    NaN
#  3    NaN
#  4    NaN
#  5    NaN
#  6    NaN
#  7    NaN
#  8    NaN
#  9    NaN
#  10   NaN
#  11   NaN  ,
#                            Type       Last    Chg.    Chg.%  Time
#  0      Серебро Цена на серебро    14.9870 -3.1630 -17.4270   NaN
#  1      Платина Цены на платину   872.6000  7.3000   0.8000   NaN
#  2    Палладий Цена на палладий  1462.9500 -5.9500  -0.4100   NaN
#  3      Медь Цена меди на бирже     2.5505  0.0025   0.0981   NaN
#  4  Золото Цена золота на бирже  1545.6400  3.3600   0.2200   NaN,
#                                  Type    Last   Chg.  Chg.%  Time
#  0               Яндекс Акции яндекса   36.51   0.00   0.00   NaN
#  1          Microsoft Microsoft Corp.  135.31  28.03  26.13   NaN
#  2                  APPLE Акции APPLE  204.16   0.00   0.00   NaN
#  3                Toyota Акции Тойоты  120.94   0.00   0.00   NaN
#  4   Volkswagen Курс акций Volkswagen  144.33  -1.14  -0.78   NaN
#  5       Facebook Цена акций Facebook  181.25   0.00   0.00   NaN
#  6          Tesla Цены на акции Тесла  214.07   0.00   0.00   NaN
#  7          Twiter Цена акций твитера   41.90   0.00   0.00   NaN
#  8  Hasbro Цена на акции Hasbro, Inc.  107.20  22.33  26.31   NaN,
#                                                  Type       Last      Chg.  \
#  0                         EURUSD Курс евро к доллару    1.10835  -0.00056
#  1   AUDUSD Курс австралийского доллара к доллару сша    0.71501   0.04007
#  2         AUDCAD Australian Dollar / Canadian Dollar    0.95727   0.06084
#  3                          EURCHF Euro / Swiss Franc    1.14008   0.05220
#  4                  EURGBP Euro / Great Britain Pound    0.90789   0.00596
#  5                         EURJPY Euro / Japanese Yen  125.80000   8.57000
#  6          GBPJPY Great Britain Pound / Japanese Yen  145.40200  15.54400
#  7                        GBPUSD Курс фунта к доллару    1.22051  -0.00821
#  8       USDCAD Курс канадского доллара к доллару сша    1.33885   0.01077
#  9              NZDUSD New Zealand Dollar / US Dollar    0.66833   0.03251
#  10                    USDCHF US Dollar / Swiss Franc    1.01425   0.03324
#  11         USDCNH Курс китайского юаня к доллару США    7.16590   0.00269
#  12                        USDJPY Курс йены к доллару  111.93100   6.22900
#
#         Chg.%  Time
#  0   -0.05050   NaN
#  1    5.93682   NaN
#  2    6.78692   NaN
#  3    4.79832   NaN
#  4    0.66081   NaN
#  5    7.31000   NaN
#  6   11.97000   NaN
#  7   -0.66818   NaN
#  8    0.81095   NaN
#  9    5.11308   NaN
#  10   3.38834   NaN
#  11   0.03755   NaN
#  12   5.89300   NaN  ,
#                                                   Type           Last  \
#  0                               Bitcoin Курс биткоина   10177.600000
#  1          Litecoin Курс лайткоин к доллару (LTC/USD)      72.300000
#  2   BitcoinCash Курс Биткоин кеш к доллару США (BC...     306.470000
#  3                                           Dash Dash      89.000000
#  4                                       Ripple Ripple       0.266590
#  5                                   Ethereum Ethereum     186.039000
#  6                                   EmerCoin EmerCoin       0.140050
#  7                                   NameCoin NameCoin       0.274000
#  8                                   PeerCoin PeerCoin       1.300000
#  9                             BTCRUB биткоин в рублях  247059.000000
#  10                              BTCEUR биткоин в евро    9128.280000
#  11                                        Zcash (ZEC)      49.832000
#  12                                          NEO (NEO)       9.483000
#  13                                          EOS (EOS)       3.532300
#  14                                         TRON (TRX)       0.017301
#  15                                             Monero      78.377000
#  16                                            Cardano       0.048875
#  17                                               IOTA       0.259050
#  18                       ETC/USD эфириум классик, ETC       6.888200
#
#           Chg.      Chg.%  Time
#  0     +37.300   0.368000   NaN
#  1        -0.6  -0.800000   NaN
#  2      +0.410   0.134000   NaN
#  3      -1.480  -1.636000   NaN
#  4    -0.00127  -0.474130   NaN
#  5      -0.600  -0.321000   NaN
#  6     0.00000   0.000000   NaN
#  7      -0.051 -15.692000   NaN
#  8       +0.16  14.040000   NaN
#  9   -3 097.00  -1.240000   NaN
#  10    +47.830   0.527000   NaN
#  11     -0.689  -1.364000   NaN
#  12     -0.123  -1.284000   NaN
#  13    -0.0236  -0.663700   NaN
#  14  -0.000299  -1.698864   NaN
#  15     -0.186  -0.237000   NaN
#  16  -0.000975  -1.955868   NaN
#  17   -0.00091  -0.350050   NaN
#  18    -0.3162  -4.389000   NaN  ,
#                                         Type       Last    Chg.  Chg.%  Time
#  0   Фьючерс РТС Курс фьючерса на индекс РТС  118130.00    0.00   0.00   NaN
#  1                      РТС Курс индекса РТС    1254.60   -4.15  -0.33   NaN
#  2                                     DAX30   12270.70  564.60   4.80   NaN
#  3                       Индекс Dow 30 (DJI)   25633.00 -126.00  -0.00   NaN
#  4                                      FTSE    7137.70   75.30   1.10   NaN
#  5                                    CAC 40    5279.70    0.00   0.00   NaN
#  6                                Nasdaq 100    7525.15  -37.86  -0.50   NaN
#  7                              Russell 2000    1594.50    6.20   0.40   NaN
#  8                                   S&P 500    2816.30   10.80   0.40   NaN
#  9                                   IBEX 35    9595.40  891.20  10.20   NaN
#  10                               Nikkei 225   21779.00   39.00   0.00   NaN
#  11                            Euro Stoxx 50    3513.20  155.60   4.60   NaN
#  12                                  S&P 500    2904.60   37.00   1.30   NaN
#  13                              S&P/ASX 200    6288.50 -172.60  -2.70   NaN
#  14                                      MIB   20852.00 -153.00  -1.00   NaN,
#                                 Type     Last    Chg.   Chg.%  Time
#  0  EURRUB Курс евро к рублю сегодня  73.9651  0.0504  0.0682   NaN
#  1       USDRUB Курс рубля к доллару  66.7916  0.6626  1.0020   NaN]

# %%
# одна таблица
pd.read_html('https://fortrader.org/quotes')[1]
# Out:
#                                     Type          Last      Chg.     Chg.%  \
# 0                      ВТБ Акции ОАО ВТБ       0.03814  -0.00015  -0.39175
# 1                 Газпром Акции газпрома     226.92000     +2.05   0.91000
# 2                    Лукоил Акции Лукойл    5171.50000    +109.5   2.20000
# 3                Роснефть Акции Роснефти     404.10000     -0.70  -0.17000
# 4               Сбербанк Акции Сбербанка     217.20000     -0.02  -0.01000
# 5   Сургутнефтегаз Акции Сургутнефтегаза      25.91000    +0.130   0.50400
# 6              Норникель Акции Норникель   15408.00000       -18  -0.00000
# 7               Аэрофлот Акции Аерофлота     109.00000    +12.19  12.59000
# 8            Северсталь Акции Северсталь     951.20000      +3.4   0.40000
# 9            Транснефть Акции транснефти  150050.00000   -16 250 -10.00000
# 10     Ростелеком Курс акций ростелекома      80.80000     +7.97  10.94000
# 11                     RUSAL акции RUSAL       3.08000     +0.01   0.33000
#
#     Time
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
